# %%
import pandas as pd
import numpy as np
import seaborn as sns

sns.set(rc={"figure.figsize":[10,10]} , font_scale = 1.4)

# %%
data = pd.read_csv("data.csv")
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.head(65)
# Out:
#                    date      price  bedrooms  bathrooms  sqft_living  \
# 0   2014-05-02 00:00:00   313000.0       3.0       1.50         1340
# 1   2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 2   2014-05-02 00:00:00   342000.0       3.0       2.00         1930
# 3   2014-05-02 00:00:00   420000.0       3.0       2.25         2000
# 4   2014-05-02 00:00:00   550000.0       4.0       2.50         1940
# ..                  ...        ...       ...        ...          ...
# 60  2014-05-02 00:00:00   555000.0       4.0       2.50         3310
# 61  2014-05-02 00:00:00   459990.0       3.0       2.50         2680
# 62  2014-05-02 00:00:00   625000.0       4.0       3.25         2730
# 63  2014-05-02 00:00:00   300000.0       3.0       2.50         2540
# 64  2014-05-03 00:00:00   625000.0       4.0       2.75         2920
#
#     sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
data.corr()["price"]
# Out:
# price            1.000000
# bedrooms         0.200336
# bathrooms        0.327110
# sqft_living      0.430410
# sqft_lot         0.050451
# floors           0.151461
# waterfront       0.135648
# view             0.228504
# condition        0.034915
# sqft_above       0.367570
# sqft_basement    0.210427
# yr_built         0.021857
# yr_renovated    -0.028774
# Name: price, dtype: float64

# %%
data = data[["date" , "price" , "bedrooms" , "bathrooms" , "sqft_living" , "floors" , "waterfront" , "view" , "sqft_above" , "sqft_basement" , "street" , "city" , "statezip" , "country"]]
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       floors  waterfront  view  sqft_above  sqft_basement  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   sqft_above     4600 non-null   int64
#  9   sqft_basement  4600 non-null   int64
#  10  street         4600 non-null   object
#  11  city           4600 non-null   object
#  12  statezip       4600 non-null   object
#  13  country        4600 non-null   object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 503.2+ KB

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living       floors  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4600.000000
# mean   5.519630e+05     3.400870     2.160815   2139.346957     1.512065
# std    5.638347e+05     0.908848     0.783781    963.206916     0.538288
# min    0.000000e+00     0.000000     0.000000    370.000000     1.000000
# 25%    3.228750e+05     3.000000     1.750000   1460.000000     1.000000
# 50%    4.609435e+05     3.000000     2.250000   1980.000000     1.500000
# 75%    6.549625e+05     4.000000     2.500000   2620.000000     2.000000
# max    2.659000e+07     9.000000     8.000000  13540.000000     3.500000
#
#         waterfront         view   sqft_above  sqft_basement
# count  4600.000000  4600.000000  4600.000000    4600.000000
# mean      0.007174     0.240652  1827.265435     312.081522
# std       0.084404     0.778405   862.168977     464.137228
# min       0.000000     0.000000   370.000000       0.000000
# ...

# %%
sns.displot(data['price'],kde = True)

# %%
data[data["price"]==0]
data.loc[data["price"] == 0 , "price"] = np.nan
# Out:
# C:\Users\alaae\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4551 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   sqft_above     4600 non-null   int64
#  9   sqft_basement  4600 non-null   int64
#  10  street         4600 non-null   object
#  11  city           4600 non-null   object
#  12  statezip       4600 non-null   object
#  13  country        4600 non-null   object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 503.2+ KB

# %%
data.isnull().sum()
# Out:
# date              0
# price            49
# bedrooms          0
# bathrooms         0
# sqft_living       0
# floors            0
# waterfront        0
# view              0
# sqft_above        0
# sqft_basement     0
# street            0
# city              0
# statezip          0
# country           0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
data["price"] = imputer.fit_transform(data[["price"]])
# Out:
# <ipython-input-13-9204018ef17f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["price"] = imputer.fit_transform(data[["price"]])

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# sqft_above       0
# sqft_basement    0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
data
# Out:
# <ipython-input-15-201484ec8ace>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
#            date         price  bedrooms  bathrooms  sqft_living  floors  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340     1.5
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650     2.0
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     1.0
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000     1.0
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     1.0
# ...         ...           ...       ...        ...          ...     ...
# ...

# %%
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day_of_week'] = data['date'].dt.day_name()
data
# Out:
# <ipython-input-16-53a5a211ff26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = data['date'].dt.year
# <ipython-input-16-53a5a211ff26>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['month'] = data['date'].dt.month
# <ipython-input-16-53a5a211ff26>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data.drop("date" ,axis = 1 , inplace = True)
# Out:
# C:\Users\alaae\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data = pd.get_dummies(data , columns = ["street","city","statezip","country","day_of_week"])
data
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0     3.130000e+05       3.0       1.50         1340     1.5           0
# 1     2.384000e+06       5.0       2.50         3650     2.0           0
# 2     3.420000e+05       3.0       2.00         1930     1.0           0
# 3     4.200000e+05       3.0       2.25         2000     1.0           0
# 4     5.500000e+05       4.0       2.50         1940     1.0           0
# ...            ...       ...        ...          ...     ...         ...
# 4595  3.081667e+05       3.0       1.75         1510     1.0           0
# 4596  5.343333e+05       3.0       2.50         1460     2.0           0
# 4597  4.169042e+05       3.0       2.50         3010     2.0           0
# 4598  2.034000e+05       4.0       2.00         2090     1.0           0
# 4599  2.206000e+05       3.0       2.50         1490     2.0           0
#
#       view  sqft_above  sqft_basement  year  ...  statezip_WA 98288  \
# ...

# %%
x = data.drop('price', axis=1)
x
# Out:
#       bedrooms  bathrooms  sqft_living  floors  waterfront  view  sqft_above  \
# 0          3.0       1.50         1340     1.5           0     0        1340
# 1          5.0       2.50         3650     2.0           0     4        3370
# 2          3.0       2.00         1930     1.0           0     0        1930
# 3          3.0       2.25         2000     1.0           0     0        1000
# 4          4.0       2.50         1940     1.0           0     0        1140
# ...        ...        ...          ...     ...         ...   ...         ...
# 4595       3.0       1.75         1510     1.0           0     0        1510
# 4596       3.0       2.50         1460     2.0           0     0        1460
# 4597       3.0       2.50         3010     2.0           0     0        3010
# 4598       4.0       2.00         2090     1.0           0     0        1070
# 4599       3.0       2.50         1490     2.0           0     0        1490
#
# ...

# %%
y = data['price']
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
models = {
    "LR": LinearRegression(),
    "KNNR" : KNeighborsRegressor(), 
    "SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
    "XGBR": XGBRegressor()
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}') 
    y_pred = model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print('-----------------------------------------------------------')
# Out:
# Using model: LR
# Training Score: 0.9976277569096269
# Test Score: -3.562831927930766e+25
# RMSE: 2.153821457829866e+18
# -----------------------------------------------------------
# Using model: KNNR
# Training Score: 0.3250734120304756
# Test Score: -0.09477171549223473
# RMSE: 377549.4273092459
# -----------------------------------------------------------
# Using model: SVR
# Training Score: -0.024291406401950377
# Test Score: -0.03488581580508976
# RMSE: 367077.90876589314
# -----------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.5978761626795679
# RMSE: 228818.92488404558
# -----------------------------------------------------------
# Using model: RF
# Training Score: 0.9205311499146422
# Test Score: 0.6734807595732324
# RMSE: 206189.4406042426
# -----------------------------------------------------------
# Using model: XGBR
# Training Score: 0.9764383190294753
# Test Score: 0.6755733478703148
# ...
